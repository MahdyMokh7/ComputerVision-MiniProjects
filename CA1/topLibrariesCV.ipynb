# %% [markdown]
# ## 🥚 **BASIC LEVEL** — *Getting started with images & simple processing*
#
# ### 1. **OpenCV (`opencv-python`)**
#
# 📦 `pip install opencv-python`
#
# * 🧠 **Purpose:** The *workhorse* of computer vision.
# * 🧰 **You use it for:**
#
#   * Reading, displaying, and writing images/videos (`cv2.imread`, `cv2.imshow`, `cv2.VideoCapture`)
#   * Image processing (blur, edges, contours, color conversions)
#   * Geometric transformations (resize, rotate, crop)
#   * Object detection with classical methods (Haar cascades, HOG)
# * ⚙️ **Why:** It’s fast (C++ backend), battle-tested, and works everywhere.
# * 🔄 **Alternative:** `scikit-image` (Pythonic but slower).
#
# ---
#
# ### 2. **Pillow (`PIL`)**
#
# 📦 `pip install pillow`
#
# * 🧠 **Purpose:** Simple image manipulation and format handling.
# * 🧰 **Use it for:**
#
#   * Opening/saving images
#   * Basic editing (crop, rotate, filters, draw text)
# * ⚙️ **Why:** Great for lightweight tasks or preprocessing before deep learning.
# * 🔄 **Alternative:** `imageio` or `matplotlib.image` (for reading only).
#
# ---
#
# ### 3. **Matplotlib / Seaborn**
#
# 📦 `pip install matplotlib`
#
# * 🧠 **Purpose:** Visualization.
# * 🧰 **Use it for:** Displaying images inline, plotting histograms, and debugging CV tasks.
#
# ---
#
# ### 4. **NumPy**
#
# 📦 `pip install numpy`
#
# * 🧠 **Purpose:** Backbone for image operations (since images = arrays).
# * 🧰 **Use it for:** Arithmetic on pixels, masks, filters, etc.
#
# ---
#
# ## ⚙️ **INTERMEDIATE LEVEL** — *Feature extraction, ML models, and deep learning prep*
#
# ### 5. **scikit-image**
#
# 📦 `pip install scikit-image`
#
# * 🧠 **Purpose:** Image analysis with ready-made algorithms.
# * 🧰 **Use it for:**
#
#   * Edge detection, segmentation, morphology
#   * Feature extraction (ORB, HOG)
#   * Image filters and transformations
# * 🔄 **Alternative:** Similar features exist in OpenCV, but scikit-image is more “Pythonic.”
#
# ---
#
# ### 6. **scikit-learn**
#
# 📦 `pip install scikit-learn`
#
# * 🧠 **Purpose:** Classical machine learning.
# * 🧰 **Use it for:** Training SVMs, KNNs, or clustering models on extracted image features.
#
# ---
#
# ### 7. **mediapipe**
#
# 📦 `pip install mediapipe`
#
# * 🧠 **Purpose:** Google’s framework for real-time CV (ready-to-use models).
# * 🧰 **Use it for:**
#
#   * Face detection / landmarks
#   * Hand tracking
#   * Pose estimation
#   * Object detection (lightweight, mobile-friendly)
# * ⚙️ **Why:** Fast and easy; no training needed.
#
# ---
#
# ## 🚀 **ADVANCED LEVEL** — *Deep learning, neural networks, and large-scale CV*
#
# ### 8. **PyTorch**
#
# 📦 `pip install torch torchvision`
#
# * 🧠 **Purpose:** Deep learning framework.
# * 🧰 **Use it for:**
#
#   * Building and training CNNs (Convolutional Neural Networks)
#   * Transfer learning (ResNet, VGG, MobileNet, etc.)
#   * Custom object detection or segmentation.
# * ⚙️ **Why:** Hugely popular, flexible, and great ecosystem.
# * 🔄 **Alternative:** TensorFlow + Keras.
#
# ---
#
# ### 9. **TensorFlow / Keras**
#
# 📦 `pip install tensorflow`
#
# * 🧠 **Purpose:** Deep learning with a higher-level API (Keras).
# * 🧰 **Use it for:**
#
#   * Classification, detection, segmentation
#   * Training or deploying CV models easily
# * ⚙️ **Why:** Easier to deploy on mobile/web (TensorFlow Lite, TF.js)
#
# ---
#
# ### 10. **Detectron2 / MMDetection / YOLO frameworks**
#
# * 🧠 **Purpose:** State-of-the-art *object detection* and *segmentation*.
# * 🧰 **Use it for:**
#
#   * Object detection (YOLOv5/8)
#   * Instance segmentation (Mask R-CNN)
#   * Keypoint detection
# * ⚙️ **Why:** These are pre-built pipelines for real-world CV applications.
#
# ---
#
# ### 11. **OpenMMLab / Hugging Face Transformers**
#
# 📦 `pip install transformers`
#
# * 🧠 **Purpose:** Vision Transformers (ViT), CLIP, SAM, etc.
# * 🧰 **Use it for:**
#
#   * Combining vision and language (e.g., image captioning, zero-shot detection).
#   * Using pretrained models without training from scratch.
#
# ---
#
# ### 12. **Albumentations**
#
# 📦 `pip install albumentations`
#
# * 🧠 **Purpose:** Image augmentation for deep learning.
# * 🧰 **Use it for:** Random crops, rotations, color jitter, flips — fast and flexible.
# * ⚙️ **Why:** Better than manual OpenCV augmentation.
#
# ---
#
# ## 🗂️ **BONUS: Utility & Visualization Tools**
#
# | Library                           | Purpose                              |
# | --------------------------------- | ------------------------------------ |
# | **imageio**                       | Reading/writing images, GIFs, videos |
# | **tqdm**                          | Progress bars for training loops     |
# | **matplotlib / seaborn / plotly** | Visualization                        |
# | **labelImg / roboflow**           | Annotating datasets                  |
# | **gradio / streamlit**            | Building quick CV demos              |
#
# ---
#
# ## 🧭 **How to Learn Them Progressively**
#
# | Level        | Focus                            | Example Project                       |
# | ------------ | -------------------------------- | ------------------------------------- |
# | Beginner     | Image I/O, filters, edges        | Face blur app with OpenCV             |
# | Intermediate | Feature extraction, classical ML | Handwritten digit classifier          |
# | Advanced     | CNNs, object detection           | Real-time YOLO or pose estimation app |
